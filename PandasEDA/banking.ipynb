# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\lavan\Desktop\ML_projects\ml_training\fd_data_5000_rows.xlsx")

# %%
df.head()
# Out:
#    srno    person  amount     fdno   interest     bank        date
# 0     1  Person_1  314037  15081625      7.92   Bank_6  29/08/2035
# 1     2  Person_2  709132   4530825      8.72   Bank_3  01/01/2035
# 2     3  Person_3  354311  54783891      7.87   Bank_7  20/09/2035
# 3     4  Person_4  957716  94587851      9.48  Bank_10  21/09/2030
# 4     5  Person_5  374453   1322946      7.45   Bank_1  29/02/2032

# %%
df[['day', 'month', 'year']] = df['date'].str.split('/',expand=True)

# %%
df.head(10)
# Out:
#    srno     person  amount     fdno   interest     bank        date day month  \
# 0     1   Person_1  314037  15081625      7.92   Bank_6  29/08/2035  29    08
# 1     2   Person_2  709132   4530825      8.72   Bank_3  01/01/2035  01    01
# 2     3   Person_3  354311  54783891      7.87   Bank_7  20/09/2035  20    09
# 3     4   Person_4  957716  94587851      9.48  Bank_10  21/09/2030  21    09
# 4     5   Person_5  374453   1322946      7.45   Bank_1  29/02/2032  29    02
# 5     6   Person_6  910238   6380028      8.89   Bank_9  04/12/2031  04    12
# 6     7   Person_7  290294  43716446      7.42   Bank_9  08/03/2028  08    03
# 7     8   Person_8  378307  43651661      8.31   Bank_3  30/12/2032  30    12
# 8     9   Person_9  351388  26090329      9.90   Bank_9  18/09/2034  18    09
# 9    10  Person_10  748218  15384736      9.72   Bank_9  04/02/2030  04    02
#
#    year
# 0  2035
# 1  2035
# 2  2035
# 3  2030
# 4  2032
# 5  2031
# 6  2028
# 7  2032
# 8  2034
# 9  2030

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   srno      5000 non-null   int64
#  1   person    5000 non-null   str
#  2   amount    5000 non-null   int64
#  3   fdno      5000 non-null   int64
#  4   interest  5000 non-null   float64
#  5   bank      5000 non-null   str
#  6   date      5000 non-null   str
#  7   day       5000 non-null   str
#  8   month     5000 non-null   str
#  9   year      5000 non-null   str
# dtypes: float64(1), int64(3), str(6)
# memory usage: 390.8 KB

# %%
df['principal']=df['amount']+(df['amount']*df['interest'])

# %%
df
# Out:
#       srno     person  amount     fdno   interest     bank        date day  \
# 0        1   Person_1  314037  15081625      7.92   Bank_6  29/08/2035  29
# 1        2   Person_2  709132   4530825      8.72   Bank_3  01/01/2035  01
# 2        3   Person_3  354311  54783891      7.87   Bank_7  20/09/2035  20
# 3        4   Person_4  957716  94587851      9.48  Bank_10  21/09/2030  21
# 4        5   Person_5  374453   1322946      7.45   Bank_1  29/02/2032  29
# ...    ...        ...     ...       ...       ...      ...         ...  ..
# 4995  4996  Person_46  721303  31410919      8.91   Bank_1  06/04/2029  06
# 4996  4997  Person_47  173901  19346554      7.32   Bank_7  17/07/2034  17
# 4997  4998  Person_48  196370  99476879      9.93   Bank_6  28/11/2026  28
# 4998  4999  Person_49  472088  34280664      7.11   Bank_8  29/11/2032  29
# 4999  5000  Person_50  411411  91981075      7.21  Bank_10  19/09/2026  19
#
#      month  year    principal
# 0       08  2035   2801210.04
# ...

# %%
df_1=df.sort_values(['principal'],ascending=False)

# %%
df_1.groupby(['person','principal'])

# %%
df_1
# Out:
#       srno     person  amount     fdno   interest    bank        date day  \
# 4658  4659   Person_9  990154  45809215      9.98  Bank_9  24/10/2027  24
# 564    565  Person_15  995307  96822659      9.92  Bank_4  02/12/2031  02
# 1411  1412  Person_12  983839  64945021      9.99  Bank_4  10/03/2029  10
# 2995  2996  Person_46  989007  29984755      9.84  Bank_1  07/03/2035  07
# 4220  4221  Person_21  999029  56899737      9.73  Bank_6  30/10/2026  30
# ...    ...        ...     ...       ...       ...     ...         ...  ..
# 203    204   Person_4  104822  28090884      7.16  Bank_3  16/03/2030  16
# 4460  4461  Person_11  100735  42663213      7.43  Bank_8  15/02/2031  15
# 3106  3107   Person_7  100997  77773279      7.30  Bank_8  16/04/2035  16
# 3022  3023  Person_23  103794   2405295      7.02  Bank_9  28/09/2031  28
# 3795  3796  Person_46  102789  93002675      7.05  Bank_6  30/08/2029  30
#
#      month  year    principal
# 4658    10  2027  10871890.92
# ...

# %%
df_2=df.sort_values(['interest'],ascending=False)

# %%
df_2

# %%
df_1.groupby(['person','interest']).count()
# Out:
#                    srno  amount  fdno   bank  date  day  month  year  \
# person   interest
# Person_1 7.05         1       1      1     1     1    1      1     1
#          7.07         1       1      1     1     1    1      1     1
#          7.09         1       1      1     1     1    1      1     1
#          7.12         1       1      1     1     1    1      1     1
#          7.15         1       1      1     1     1    1      1     1
# ...                 ...     ...    ...   ...   ...  ...    ...   ...
# Person_9 9.90         2       2      2     2     2    2      2     2
#          9.91         1       1      1     1     1    1      1     1
#          9.96         1       1      1     1     1    1      1     1
#          9.97         2       2      2     2     2    2      2     2
#          9.98         1       1      1     1     1    1      1     1
#
#                    principal
# person   interest
# Person_1 7.05              1
#          7.07              1
# ...
