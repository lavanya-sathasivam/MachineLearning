# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\lavan\Desktop\ML_projects\ml_training\datasets\europe11.csv")

# %%
df.head()
# Out:
#           Country    Area    GDP  Inflation  Life.expect  Military  \
# 0         Austria   83871  41600        3.5        79.91      0.80
# 1         Belgium   30528  37800        3.5        79.65      1.30
# 2        Bulgaria  110879  13800        4.2        73.84      2.60
# 3         Croatia   56594  18000        2.3        75.99      2.39
# 4  Czech Republic   78867  27100        1.9        77.38      1.15
#
#    Pop.growth  Unemployment
# 0        0.03           4.2
# 1        0.06           7.2
# 2       -0.80           9.6
# 3       -0.09          17.7
# 4       -0.13           8.5

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Encoded Country"]=le.fit_transform(df["Country"])

# %%
df=df.drop(['Encoded Country'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       28 non-null     str
#  1   Area          28 non-null     int64
#  2   GDP           28 non-null     int64
#  3   Inflation     28 non-null     float64
#  4   Life.expect   28 non-null     float64
#  5   Military      28 non-null     float64
#  6   Pop.growth    28 non-null     float64
#  7   Unemployment  28 non-null     float64
# dtypes: float64(5), int64(2), str(1)
# memory usage: 1.9 KB

# %%
df=df.drop(['Country'],axis=1)

# %%
df.head()
# Out:
#      Area    GDP  Inflation  Life.expect  Military  Pop.growth  Unemployment
# 0   83871  41600        3.5        79.91      0.80        0.03           4.2
# 1   30528  37800        3.5        79.65      1.30        0.06           7.2
# 2  110879  13800        4.2        73.84      2.60       -0.80           9.6
# 3   56594  18000        2.3        75.99      2.39       -0.09          17.7
# 4   78867  27100        1.9        77.38      1.15       -0.13           8.5

# %%
df.isna().sum()
# Out:
# Area            0
# GDP             0
# Inflation       0
# Life.expect     0
# Military        0
# Pop.growth      0
# Unemployment    0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss=[]
for i in range(1,10):
    kmeans=KMeans(n_clusters=i,max_iter=300,random_state=42)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,10),wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans=KMeans(n_clusters=3,max_iter=300,random_state=0)

# %%
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
y_pred=kmeans.predict(df)

# %%
df['Category']=y_pred

# %%
df
# Out:
#       Area    GDP  Inflation  Life.expect  Military  Pop.growth  Unemployment  \
# 0    83871  41600        3.5        79.91      0.80        0.03           4.2
# 1    30528  37800        3.5        79.65      1.30        0.06           7.2
# 2   110879  13800        4.2        73.84      2.60       -0.80           9.6
# 3    56594  18000        2.3        75.99      2.39       -0.09          17.7
# 4    78867  27100        1.9        77.38      1.15       -0.13           8.5
# 5    43094  37000        2.8        78.78      1.30        0.24           6.1
# 6    45228  20400        5.0        73.58      2.00       -0.65          12.5
# 7   338145  36000        3.3        79.41      2.00        0.07           7.8
# 8   357022  38100        2.5        80.19      1.50       -0.20           6.0
# 9   131957  26300        3.3        80.05      4.30        0.06          17.4
# 10   93028  19600        3.9        75.02      1.75       -0.18          10.9
# ...

# %%
df.groupby('Category').count()
# Out:
#           Area  GDP  Inflation  Life.expect  Military  Pop.growth  \
# Category
# 0           19   19         19           19        19          19
# 1            3    3          3            3         3           3
# 2            6    6          6            6         6           6
#
#           Unemployment  Encoded Country
# Category
# 0                   19               19
# 1                    3                3
# 2                    6                6
