# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\lavan\Desktop\ML_projects\ml_training\datasets\country.xlsx")

# %%
df
# Out:
#        Country    Lat    Long Language
# 0      Austria  47.68   13.33  english
# 1      beljium  50.63    4.67  english
# 2      germany  51.15   10.43   german
# 3       norway  64.00   18.30  english
# 4        India  22.00   78.00    hindi
# 5    sreelanka   7.66   80.63  simhala
# 6    Australia -10.45  113.09  english
# 7  southafrica -30.00   25.00  english

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Language_Code"]=le.fit_transform(df["Language"])
print(df)
# Out:
#        Country    Lat    Long Language  Language_Code
# 0      Austria  47.68   13.33  english              0
# 1      beljium  50.63    4.67  english              0
# 2      germany  51.15   10.43   german              1
# 3       norway  64.00   18.30  english              0
# 4        India  22.00   78.00    hindi              2
# 5    sreelanka   7.66   80.63  simhala              3
# 6    Australia -10.45  113.09  english              0
# 7  southafrica -30.00   25.00  english              0

# %%
X=df[["Lat","Long","Language_Code"]]

# %%
import seaborn as sns

# %%
co=X.corr()

# %%
sns.heatmap(co,vmax=1,vmin=-1,annot=True,linewidths=5,cmap='bwr')
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
kmeans=KMeans(n_clusters=3,max_iter=300,random_state=0)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
y_pred=kmeans.predict(X)

# %%
y_pred
# Out:
# array([1, 1, 1, 1, 0, 0, 0, 2], dtype=int32)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
wcss=[]
for i in range(1,8):
    kmeans=KMeans(n_clusters=i,max_iter=300,random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,8),wcss)
plt.title("Elbow Method")
plt.xlabel("Number of Clusters")
plt.ylabel("WCSS")
plt.show()

# %%
df['Category']=y_pred

# %%
df
# Out:
#        Country    Lat    Long Language  Language_Code  Category
# 0      Austria  47.68   13.33  english              0         1
# 1      beljium  50.63    4.67  english              0         1
# 2      germany  51.15   10.43   german              1         1
# 3       norway  64.00   18.30  english              0         1
# 4        India  22.00   78.00    hindi              2         0
# 5    sreelanka   7.66   80.63  simhala              3         0
# 6    Australia -10.45  113.09  english              0         0
# 7  southafrica -30.00   25.00  english              0         2
