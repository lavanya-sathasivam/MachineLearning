# %%
import pandas as pd
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import pickle
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv(r"dataset.csv")
df.shape
# Out:
# (1520, 9)

# %%
df
# Out:
#         ID   model  engine_power  age_in_days      km  previous_owners  \
# 0        1  lounge            51          882   25000                1
# 1        2     pop            51         1186   32500                1
# 2        3   sport            74         4658  142228                1
# 3        4  lounge            51         2739  160000                1
# 4        5     pop            73         3074  106880                1
# ...    ...     ...           ...          ...     ...              ...
# 1515  1534   sport            51         3712  115280                1
# 1516  1535  lounge            74         3835  112000                1
# 1517  1536     pop            51         2223   60457                1
# 1518  1537  lounge            51         2557   80750                1
# 1519  1538     pop            51         1766   54276                1
#
#             lat        lon  price
# 0     44.907242   8.611560   8900
# 1     45.666359  12.241890   8800
# ...

# %%
df.describe()
# Out:
#                 ID  engine_power  age_in_days             km  previous_owners  \
# count  1520.000000   1520.000000  1520.000000    1520.000000      1520.000000
# mean    768.854605     51.915132  1657.190789   53602.474342         1.123684
# std     443.599478      4.010360  1290.870689   40181.202940         0.415901
# min       1.000000     51.000000   366.000000    1232.000000         1.000000
# 25%     383.750000     51.000000   670.000000   20000.000000         1.000000
# 50%     769.500000     51.000000  1066.000000   39162.000000         1.000000
# 75%    1151.250000     51.000000  2623.750000   80000.000000         1.000000
# max    1538.000000     77.000000  4658.000000  235000.000000         4.000000
#
#                lat          lon         price
# count  1520.000000  1520.000000   1520.000000
# mean     43.539485    11.571552   8564.311842
# std       2.137960     2.332344   1942.771619
# min      36.855839     7.245400   2500.000000
# ...

# %%
list(df)
# Out:
# ['ID',
#  'model',
#  'engine_power',
#  'age_in_days',
#  'km',
#  'previous_owners',
#  'lat',
#  'lon',
#  'price']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               1520 non-null   int64
#  1   model            1520 non-null   str
#  2   engine_power     1520 non-null   int64
#  3   age_in_days      1520 non-null   int64
#  4   km               1520 non-null   int64
#  5   previous_owners  1520 non-null   int64
#  6   lat              1520 non-null   float64
#  7   lon              1520 non-null   float64
#  8   price            1520 non-null   int64
# dtypes: float64(2), int64(6), str(1)
# memory usage: 107.0 KB

# %%
df1=df.drop(['ID','lat','lon'],axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   model            1520 non-null   str
#  1   engine_power     1520 non-null   int64
#  2   age_in_days      1520 non-null   int64
#  3   km               1520 non-null   int64
#  4   previous_owners  1520 non-null   int64
#  5   price            1520 non-null   int64
# dtypes: int64(5), str(1)
# memory usage: 71.4 KB

# %%
df1['engine_power'].unique()
# Out:
# array([51, 74, 73, 62, 63, 66, 77, 58])

# %%
df1=pd.get_dummies(df1,dtype=int)

# %%
df1
# Out:
#       engine_power  age_in_days      km  previous_owners  price  model_lounge  \
# 0               51          882   25000                1   8900             1
# 1               51         1186   32500                1   8800             0
# 2               74         4658  142228                1   4200             0
# 3               51         2739  160000                1   6000             1
# 4               73         3074  106880                1   5700             0
# ...            ...          ...     ...              ...    ...           ...
# 1515            51         3712  115280                1   5200             0
# 1516            74         3835  112000                1   4600             1
# 1517            51         2223   60457                1   7500             0
# 1518            51         2557   80750                1   5990             1
# 1519            51         1766   54276                1   7900             0
#
#       model_pop  model_sport
# ...

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   engine_power     1520 non-null   int64
#  1   age_in_days      1520 non-null   int64
#  2   km               1520 non-null   int64
#  3   previous_owners  1520 non-null   int64
#  4   price            1520 non-null   int64
#  5   model_lounge     1520 non-null   int64
#  6   model_pop        1520 non-null   int64
#  7   model_sport      1520 non-null   int64
# dtypes: int64(8)
# memory usage: 95.1 KB

# %%
cor=df1.corr()

# %%
sns.heatmap(cor,vmax=1,vmin=-1,linewidths=5,annot=True,cmap='bwr')
# Out:
# <Axes: >

# %%
x=df1.drop(['price'],axis=1)
y=df1['price']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
mod=LinearRegression()
mod.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
ypred_linear=mod.predict(xtest)

# %%
msc=mean_squared_error(ytest,ypred_linear)
msc
# Out:
# 621356.7376116506

# %%
r2=r2_score(ytest,ypred_linear)
r2*100
# Out:
# 84.26747754831847

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1520 entries, 0 to 1519
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   engine_power     1520 non-null   int64
#  1   age_in_days      1520 non-null   int64
#  2   km               1520 non-null   int64
#  3   previous_owners  1520 non-null   int64
#  4   price            1520 non-null   int64
#  5   model_lounge     1520 non-null   int64
#  6   model_pop        1520 non-null   int64
#  7   model_sport      1520 non-null   int64
# dtypes: int64(8)
# memory usage: 95.1 KB

# %%
new=[[51,2967,100000,1,1,0,0],[51,4127,125000,1,1,0,0],[51,6324,175000,1,1,0,0]]
ans=mod.predict(new)

# %%
ans
# Out:
# array([6658.65424249, 5215.70681634, 2434.96727388])

# %%
pickle.dump(mod,open("fiatmodel","wb"))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge

# %%
alpha=[1e-15,1e-10,1e-8,1e-4,1e-3,1e-2,1,5,10,20,30]

# %%
ridge=Ridge()

# %%
parameters={'alpha':alpha}

# %%
ridge_reg=GridSearchCV(ridge,parameters)

# %%
ridge_reg.fit(xtrain,ytrain)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1e-15, 1e-10, 1e-08, 0.0001, 0.001, 0.01, 1,
#                                    5, 10, 20, 30]})

# %%
ridge_reg.best_params_
# Out:
# {'alpha': 30}

# %%
ridge=Ridge(alpha=20)

# %%
ridge.fit(xtrain,ytrain)
# Out:
# Ridge(alpha=20)

# %%
ypred_ridge=ridge.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
msc=mean_squared_error(ytest,ypred_ridge)

# %%
msc
# Out:
# 621024.4702798801

# %%
r2=r2_score(ytest,ypred_ridge)

# %%
r2
# Out:
# 0.8427589043409024

# %%
d = pd.DataFrame({"actual": ytest, "predicted_linear": ypred_linear,"predicted_ridge":ypred_ridge})

# %%
d['Id']=d.index

# %%
d=d.reset_index(drop=True)

# %%
d.head(10)
# Out:
#    actual  predicted_linear  predicted_ridge    Id
# 0    9980       9719.960433      9716.446964   461
# 1    9600       9927.401780      9923.855009  1314
# 2    6800       6578.086342      6591.774929  1472
# 3    9890      10298.907744     10295.262378   744
# 4   10500       9198.355611      9195.503324   247
# 5    7950       6782.125843      6779.179029   430
# 6    9490       9747.187306      9743.649199   939
# 7    9950      10088.170527     10084.536038  1490
# 8    8579       9690.840690      9687.329455   358
# 9    9450       9505.666244      9502.212561   427

# %%
offset=100.0

# %%
sns.lineplot(x='Id',y='actual',data=d.head(50))
sns.lineplot(x='Id',y='predicted_linear',data=d.head(50))
sns.lineplot(x='Id',y=d.head(50)['predicted_ridge'] + offset,data=d.head(50))
plt.plot()
# Out:
# []
