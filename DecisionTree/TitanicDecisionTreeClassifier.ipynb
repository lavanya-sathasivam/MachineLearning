# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
list(df)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df.groupby(['Pclass','Survived']).count()
# Out:
#                  PassengerId  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived
# 1      0                  80    80   80   64     80     80      80    80
#        1                 136   136  136  122    136    136     136   136
# 2      0                  97    97   97   90     97     97      97    97
#        1                  87    87   87   83     87     87      87    87
# 3      0                 372   372  372  270    372    372     372   372
#        1                 119   119  119   85    119    119     119   119
#
#                  Cabin  Embarked
# Pclass Survived
# 1      0            59        80
#        1           117       134
# 2      0             3        97
#        1            13        87
# 3      0             6       372
#        1             6       119

# %%
df.groupby(['Sex','Survived']).count()
# Out:
#                  PassengerId  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex    Survived
# female 0                  81      81    81   64     81     81      81    81
#        1                 233     233   233  197    233    233     233   233
# male   0                 468     468   468  360    468    468     468   468
#        1                 109     109   109   93    109    109     109   109
#
#                  Cabin  Embarked
# Sex    Survived
# female 0             6        81
#        1            91       231
# male   0            62       468
#        1            45       109

# %%
df.groupby(['Pclass','Survived','Sex']).count()
# Out:
#                         PassengerId  Name  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived Sex
# 1      0        female            3     3    3      3      3       3     3
#                 male             77    77   61     77     77      77    77
#        1        female           91    91   82     91     91      91    91
#                 male             45    45   40     45     45      45    45
# 2      0        female            6     6    6      6      6       6     6
#                 male             91    91   84     91     91      91    91
#        1        female           70    70   68     70     70      70    70
#                 male             17    17   15     17     17      17    17
# 3      0        female           72    72   55     72     72      72    72
#                 male            300   300  215    300    300     300   300
#        1        female           72    72   47     72     72      72    72
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df1=df.drop(['PassengerId','Name','Cabin','Ticket'],axis=1)

# %%
df1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
df1['Sex']=df1['Sex'].map({'male':1,'female':0})

# %%
df1['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.boxplot(df1.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
df1[df1['Age']>60].count()
# Out:
# Survived    22
# Pclass      22
# Sex         22
# Age         22
# SibSp       22
# Parch       22
# Fare        22
# Embarked    21
# dtype: int64

# %%
plt.hist(df1['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df1.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
df1.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
nv=df1["Age"].mean()
nv
# Out:
# np.float64(29.69911764705882)

# %%
df1['Age'].fillna(nv,inplace=True)
# Out:
# /tmp/ipykernel_5281/855338612.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Age'].fillna(nv,inplace=True)

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df1.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df1['Age']=df1['Age'].mask(df1['Age']>60,60)

# %%
plt.hist(df1['Age'])
# Out:
# (array([ 47.,  22.,  70., 138., 309., 110.,  66.,  49.,  38.,  42.]),
#  array([ 0.42 ,  6.378, 12.336, 18.294, 24.252, 30.21 , 36.168, 42.126,
#         48.084, 54.042, 60.   ]),
#  <BarContainer object of 10 artists>)

# %%
df1.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.550408    0.523008    0.381594
# std      0.486592    0.836071    0.477990   12.590301    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   60.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df1['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
em=df1['Embarked'].mode()

# %%
em
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
df1['Embarked'].fillna('S',inplace=True)
# Out:
# /tmp/ipykernel_5281/3064287390.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['Embarked'].fillna('S',inplace=True)

# %%
df1.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
df1['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df1.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.550408    0.523008    0.381594
# std      0.486592    0.836071    0.477990   12.590301    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   60.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 55.8+ KB

# %%
df1['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df1['Embarked']=df1['Embarked'].map({'S':1,'C':2,'Q':3})

# %%
df1['Embarked']
# Out:
# 0      1
# 1      2
# 2      1
# 3      1
# 4      1
#       ..
# 886    1
# 887    1
# 888    1
# 889    2
# 890    3
# Name: Embarked, Length: 891, dtype: int64

# %%
df1
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  22.000000      1      0   7.2500         1
# 1           1       1    0  38.000000      1      0  71.2833         2
# 2           1       3    0  26.000000      0      0   7.9250         1
# 3           1       1    0  35.000000      1      0  53.1000         1
# 4           0       3    1  35.000000      0      0   8.0500         1
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 886         0       2    1  27.000000      0      0  13.0000         1
# 887         1       1    0  19.000000      0      0  30.0000         1
# 888         0       3    0  29.699118      1      2  23.4500         1
# 889         1       1    1  26.000000      0      0  30.0000         2
# 890         0       3    1  32.000000      0      0   7.7500         3
#
# [891 rows x 8 columns]

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x=df1.drop(['Survived'],axis=1)
y=df1['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
model=DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
pred=model.predict(xtest)

# %%
cm=confusion_matrix(ytest,pred)
sns.heatmap(cm,annot=True)
# Out:
# <Axes: >

# %%
acc=accuracy_score(ytest,pred)
print(acc)
# Out:
# 0.7723880597014925
